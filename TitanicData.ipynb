# %% [markdown]
# <a href="https://colab.research.google.com/github/Fas96/-/blob/master/TitanicData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **데이터 분석**
# # 1. 분석 파이프라인
# # 2. 타이타닉 데이터분석

# %% [markdown]
# **데이터준비**

# %%
import pandas as pd #판다스
import matplotlib as mpl #맷플롭립
import matplotlib.pylab as plt #맷플롭립
import seaborn as sns #시본
import numpy as np #넘파이
file_path= '/content/titanic.csv'
df = pd.read_csv(file_path) #read csv()함수로 데이터프레임 변환
df
titanic_copy_backup = df.copy() #데이터 백업
# Out:
#      Unnamed: 0  PassengerId  Survived  ...     Fare Cabin Embarked
# 0             0            1         0  ...   7.2500   NaN        S
# 1             1            2         1  ...  71.2833   C85        C
# 2             2            3         1  ...   7.9250   NaN        S
# 3             3            4         1  ...  53.1000  C123        S
# 4             4            5         0  ...   8.0500   NaN        S
# ..          ...          ...       ...  ...      ...   ...      ...
# 886         886          887         0  ...  13.0000   NaN        S
# 887         887          888         1  ...  30.0000   B42        S
# 888         888          889         0  ...  23.4500   NaN        S
# 889         889          890         1  ...  30.0000  C148        C
# 890         890          891         0  ...   7.7500   NaN        Q
#
# [891 rows x 13 columns]

# %% [markdown]
# #**데이터** 백업

# %%
titanic_copy_backup
df.to_csv('/content/titanic_csv_backup.csv') #to_csv 메소드를 사용하여 내장 데이터프레임을 csv파일로 저장
file_path= '/content/titanic_csv_backup.csv'
titanic_csv_backup = pd.read_csv(file_path)
titanic_csv_backup
# Out:
#      Unnamed: 0  PassengerId  Survived  ...     Fare Cabin Embarked
# 0             0            1         0  ...   7.2500   NaN        S
# 1             1            2         1  ...  71.2833   C85        C
# 2             2            3         1  ...   7.9250   NaN        S
# 3             3            4         1  ...  53.1000  C123        S
# 4             4            5         0  ...   8.0500   NaN        S
# ..          ...          ...       ...  ...      ...   ...      ...
# 886         886          887         0  ...  13.0000   NaN        S
# 887         887          888         1  ...  30.0000   B42        S
# 888         888          889         0  ...  23.4500   NaN        S
# 889         889          890         1  ...  30.0000  C148        C
# 890         890          891         0  ...   7.7500   NaN        Q
#
# [891 rows x 13 columns]

# %% [markdown]
# # **데이터보기**

# %%
df.info() #데이터프레임의 기본 정보 출력
df.describe() #데이터프레임의 기초 통계 확인
df.dtypes # 데이터유형 확인
df.loc[0] # 데이터 행 인덱스 확인
df.head() # 상위 데이터 추출
df.tail() # 하위 데이터 추출
df.index # 데이터프레임 인덱스 보기
df.values # 행, 열 구조 보기
df.sort_values(by=['Fare'], axis=0) # 요금 기준 오름차순 정렬
df.sort_index(axis=1) #열 이름을 (알파벳 순서로) 정렬하기 : axis=1 Age부터 출력
df.sum(axis=1) # 단순열 합계
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# 0       34.2500
# 1      114.2833
# 2       40.9250
# 3       95.1000
# 4       51.0500
#          ...
# 886    929.0000
# 887    939.0000
# 888    918.4500
# 889    948.0000
# 890    933.7500
# Length: 891, dtype: float64

# %%
df.info()
df.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#      PassengerId  Survived  Pclass  ...   Fare Cabin  Embarked
# 886          887         0       2  ...  13.00   NaN         S
# 887          888         1       1  ...  30.00   B42         S
# 888          889         0       3  ...  23.45   NaN         S
# 889          890         1       1  ...  30.00  C148         C
# 890          891         0       3  ...   7.75   NaN         Q
#
# [5 rows x 12 columns]

# %% [markdown]
# # **데이터클린징**

# %%
df.count() # count the number
df.isnull().sum() # checking null values
sns.heatmap(df.isnull(),cbar=False) # 시본 시각화 확인
sns.heatmap(df.isnull(),cbar=True) # 시본 시각화 확인
import missingno as msno # missingno 패키지 임포트

msno.matrix(df) # 매트릭스 결측치 시각화
msno.bar(df) # 바챠트 결측치 시각화
msno.heatmap(df) # 히트맵 결측치 시각화
msno.dendrogram(df) # 덴드로그램 결측치 시각화

# %% [markdown]
# # **데이터클린징**2 #Cabin 결측 제거

# %%
df['Cabin'].value_counts() #Cabin 삭제전 결측치 내용 확인
df = df.dropna(thresh=int(len(df) * 0.5), axis=1) #결측치 제거
msno.matrix(df) #결측치 제거 확인

# %% [markdown]
# # **Embarked 대체**

# %%
df['Embarked'].value_counts() # 범주형 개수 확인
df['Embarked'] = df['Embarked'].fillna('S') # 최다빈도 ‘S’로 대체

# %% [markdown]
# # **나이 대체**

# %%
df['Age']=df['Age'].fillna(df['Age'].mean()) # 나이 평균값으로 대체
msno.matrix(df) #결측치 제거 최종 확인

# %% [markdown]
# # **데이터 탐색**

# %%
bins = [1, 20, 60, 100] # 1-20 미성년, 21-60 : 성년, 61-100 : 성년
df_Age = pd.cut(df["Age"], bins, labels =["미성년", "성년", "노년"])
df["Age_class"] = df_Age
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Embarked  Age_class
# 0              1         0       3  ...   7.2500        S         성년
# 1              2         1       1  ...  71.2833        C         성년
# 2              3         1       3  ...   7.9250        S         성년
# 3              4         1       1  ...  53.1000        S         성년
# 4              5         0       3  ...   8.0500        S         성년
# ..           ...       ...     ...  ...      ...      ...        ...
# 886          887         0       2  ...  13.0000        S         성년
# 887          888         1       1  ...  30.0000        S        미성년
# 888          889         0       3  ...  23.4500        S         성년
# 889          890         1       1  ...  30.0000        C         성년
# 890          891         0       3  ...   7.7500        Q         성년
#
# [891 rows x 12 columns]

# %%
t1 = df.Age_class.unique() # 범주형 중복없이 value 추출
t1
t2 = df[df.Age_class.isin(['미성년'])] # 원하는 데이터만
t2
t3 = df[~df.Age_class.isin(['미성년'])] # 원하는 데이터 제외 필터링
t3
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Embarked  Age_class
# 0              1         0       3  ...   7.2500        S         성년
# 1              2         1       1  ...  71.2833        C         성년
# 2              3         1       3  ...   7.9250        S         성년
# 3              4         1       1  ...  53.1000        S         성년
# 4              5         0       3  ...   8.0500        S         성년
# ..           ...       ...     ...  ...      ...      ...        ...
# 885          886         0       3  ...  29.1250        Q         성년
# 886          887         0       2  ...  13.0000        S         성년
# 888          889         0       3  ...  23.4500        S         성년
# 889          890         1       1  ...  30.0000        C         성년
# 890          891         0       3  ...   7.7500        Q         성년
#
# [726 rows x 12 columns]

# %% [markdown]
# # ** 전체를 3개의 범주로 구분**

# %%
df_Age2 = pd.qcut(df["Age"], q=3, labels =["미성년", "성년", "노년"])
df["Age_class2"] = df_Age2
df
# Out:
#      PassengerId  Survived  Pclass  ... Embarked Age_class  Age_class2
# 0              1         0       3  ...        S        성년         미성년
# 1              2         1       1  ...        C        성년          노년
# 2              3         1       3  ...        S        성년          성년
# 3              4         1       1  ...        S        성년          노년
# 4              5         0       3  ...        S        성년          노년
# ..           ...       ...     ...  ...      ...       ...         ...
# 886          887         0       2  ...        S        성년          성년
# 887          888         1       1  ...        S       미성년         미성년
# 888          889         0       3  ...        S        성년          성년
# 889          890         1       1  ...        C        성년          성년
# 890          891         0       3  ...        Q        성년          노년
#
# [891 rows x 13 columns]

# %% [markdown]
# # **범주형 컬럼 처리 : 원핫인코딩**

# %%
df['Sex']=df['Sex'].astype('category')
df['Pclass']=df['Pclass'].astype('category')
df['Embarked']=df['Embarked'].astype('category')

# %% [markdown]
# # ** 성별, 선실, 나이 그룹에 의한 생존율을 데이터프레임으로 계산**
# ###  행에는 성별 및 나이 그룹에 대한 다중 인덱스를 사용하고 열에는 선실 인덱스를 사용

# %%
df1 = df.groupby(['Sex','Age_class','Pclass'])["Survived"].mean()
df1
df2 = df1.unstack("Pclass")
df2
# Out:
# Pclass                   1         2         3
# Sex    Age_class
# female 미성년        0.928571  1.000000  0.465116
#        성년         0.974359  0.900000  0.489583
#        노년         1.000000       NaN  1.000000
# male   미성년        0.500000  0.357143  0.180556
#        성년         0.388350  0.069767  0.119850
#        노년         0.083333  0.333333  0.000000

# %% [markdown]
# #  피봇 **테이블**

# %%
df.pivot_table(['Survived'],index=['Sex', 'Pclass'], aggfunc='mean')
# Out:
#                Survived
# Sex    Pclass
# female 1       0.968085
#        2       0.921053
#        3       0.500000
# male   1       0.368852
#        2       0.157407
#        3       0.135447

# %% [markdown]
# # **탐색 자동보고서**

# %% [markdown]
# # **데이터 시각화 분석**

# %% [markdown]
# # 범주형 확인

# %%
sns.catplot('Sex',kind='count',data=df) # 남녀 성비 확인
sns.catplot('Pclass',kind='count',hue='Sex', data=df) # 좌석 등급별 성비 확인
sns.catplot('Embarked', kind = 'count', data = df) # 출발항구별 분포 확인
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # **연속형**

# %%
df['Age'].hist() # 나이 분포
df['Fare'].hist() # 요금 분포

# %% [markdown]
# ## 범주형*범주형

# %%
sns.catplot('Survived',kind='count',hue='Sex',data=df) # 생존자 분석
df['Survivor'] = df['Survived'].map({0 : 'no', 1: 'yes'}) # 보기 편하게 생존자 구분 변환
sns.catplot('Survivor', kind='count', hue='Sex', data=df) # 생존/성별
sns.catplot('Sex', kind='count', hue='Survivor', data=df) # 성별/생존자
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # **남자일수록 사망자가 많다.**

# %%
sns.catplot('Pclass', kind='count', hue='Survivor', data=df) # 좌석등급별 생존자 확인
sns.catplot('Embarked', kind='count', hue='Survivor', data=df) #항구별/생존
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # **연령대별/사망자 20세 미만의 아이들을 확인**

# %%
sns.catplot('Age', kind='count', hue='Survivor', data=df.loc[df['Age'] < 20])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # **연령대별/사망자 70세 이상 노인**

# %%
sns.catplot('Age', kind='count', hue='Survivor', data=df.loc[df['Age'] >=70])
sns.lmplot('Age','Survived',hue='Sex',data=df.loc[df['Age']>=20])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # P**airgrid 플롯 활용 범주 전체를 시각화 가능**
# # **생존률/성별, 객실 등급별, 탐승 항구별, 연령대 그룹별**

# %%
Pg = sns.PairGrid(df, y_vars="Survived",
x_vars=["Pclass","Sex","Embarked","Age_class"],
height=5, aspect=.7)
Pg.map(sns.pointplot, scale=1.3, errwidth=4, color="xkcd:plum")
Pg.set(ylim=(0, 1))
sns.despine(fig=Pg.fig, left=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48120 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45432 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48120 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 45432 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# # 한글처리

# %%
plt.rc('font', family='Malgun Gothic')

# %% [markdown]
# # Pairgrid bar서브플롯 적용

# %%
Pg = sns.PairGrid(df, y_vars="Survived",
x_vars=["Pclass", "Sex", "Embarked","Age_class"],
height=5, aspect=.7)
Pg.map(sns.barplot)
# Out:
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48120 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45432 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48120 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 45432 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# # Pairgrid violin서브플롯 적용

# %%
Pg.map(sns.violinplot)

# %% [markdown]
# # 범주형*연속형

# %%
#성별/나이
sns.distplot(df['Age'].loc[df['Sex']=='male'])
sns.distplot(df['Age'].loc[df['Sex']=='female'])
#생존자/나이
sns.catplot('Age', kind='count', hue='Survivor', data=df)
sns.lmplot('SibSp','Survived', hue='Sex',data=df) #여성의 경우 형제/자매가 많을 수록 사망률 증가
sns.lmplot('Parch','Survived', hue='Sex',data=df) #부모나 자식이 많은 가족의 경우 여성 사망률 증
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # 파생변수 만들기
# # 형제/자매와 부모/자식의 수를 더하여, 가족의 크기라는 특성을 생성

# %%
df['family_Size'] = df['SibSp'] + df['Parch']
sns.lmplot('family_Size','Survived', hue='Sex', data=df)
sns.lmplot('Fare','Survived', hue='Sex',data=df) #남녀 상관없이 요금의 경우 높을 수록 생존률이 높다
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # **함수생성과 파라미터 변경**
# # **생존에 따른 bar차트 함수**

# %%
def bar_chart(feature):
      Survived = df[df['Survived']==1][feature].value_counts()
      Dead = df[df['Survived']==0][feature].value_counts()
      df_titanic = pd.DataFrame([Survived,Dead])
      df_titanic.index = ['Survived','Dead']
      df_titanic.plot(kind='bar',stacked=True, figsize=(10,5))

# %% [markdown]
# # 생존/성별, 여성이 남성보다 생존할 가능성이 더 높다

# %%
bar_chart('Sex')

# %% [markdown]
# # 생존/등급별, 차트는 1등급 클래스가 다른 클래스보다 생존할 가능성이 더 높다
# # 차트는 3등급 클래스가 다른 클래스보다 죽을 가능성이 더 높다

# %%
bar_chart('Pclass')
bar_chart('Embarked') # 생존/항구별

# %% [markdown]
# # **데이터 분석  요약 **
